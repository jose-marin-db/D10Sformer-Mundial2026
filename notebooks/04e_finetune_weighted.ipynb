# %% [markdown]
# # 04e — Fine-tuning con CLASS WEIGHTS + más épocas
#
# **Proyecto:** D10Sformer — MIA305 (UdeSA, 2026)
# **Fase:** 4e — Mitigar el colapso de la clase DRAW observado en 4d
#
# ## Diagnóstico de 4d
#
# El fine-tune anterior (sin class weights) **colapsó la clase DRAW**:
# - Distribución VAL real: home=579, draw=293, away=360
# - Predicciones VAL: home=773, **draw=12**, away=447
#
# Resultado: D10Sformer perdió contra LogReg (log_loss 0.88 vs 0.86; ECE 0.040 vs 0.024).
#
# ## Hipótesis a testear
#
# Aplicar **class weights inversamente proporcionales a la frecuencia** (recipe sklearn-style):
# $$w_i = \frac{n}{k \cdot n_i}$$
#
# Donde $n$ = total samples, $k$ = num classes, $n_i$ = count clase $i$.
#
# Esto **incrementa el costo** del modelo cuando se equivoca en clases minoritarias (DRAW), forzándolo a no colapsar. Es el remedio clásico para imbalanced classification (King & Zeng, 2001).
#
# ## Cambios vs 4d
#
# 1. **Class weights** en la CE loss del Result head.
# 2. **15 épocas** (vs 10 antes) — más margen para que las clases minoritarias se acomoden.
# 3. **Mismo LR (5e-5)** y demás hyperparams.
# 4. Cargar el `best.pt` del **pre-training** (Fase 4c), no del fine-tune 4d — arrancamos limpio.
#
# ## Requisito
#
# Archivo `src/training/trainer.py` actualizado con soporte para `result_class_weights` en `LossSpec`.

# %% [markdown]
# ---
# ## 1. Setup

# %%
try:
    from google.colab import drive
    drive.mount('/content/drive')
    PROJECT_ROOT = '/content/drive/MyDrive/d10sformer'
except ImportError:
    import os
    PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), '..'))
print(f'PROJECT_ROOT = {PROJECT_ROOT}')
# Out:
# Mounted at /content/drive
# PROJECT_ROOT = /content/drive/MyDrive/d10sformer

# %%
import torch
if not torch.cuda.is_available():
    raise RuntimeError('Necesitamos GPU. Runtime → Change runtime type → T4.')
print(f'torch: {torch.__version__}  |  GPU: {torch.cuda.get_device_name(0)}')
# Out:
# torch: 2.10.0+cu128  |  GPU: Tesla T4

# %%
import sys, json, pickle
from pathlib import Path
from collections import Counter

import numpy as np
import matplotlib.pyplot as plt
import torch.nn.functional as F
from torch.utils.data import DataLoader

ROOT = Path(PROJECT_ROOT)
sys.path.insert(0, str(ROOT / 'src'))

DATA_PROCESSED = ROOT / 'data' / 'processed'
CORPUS_DIR = DATA_PROCESSED / 'corpus'
VOCAB_PATH = DATA_PROCESSED / 'vocab.json'
CKPT_DIR = ROOT / 'checkpoints'
PRETRAIN_CKPT = CKPT_DIR / 'pretrain_5ep' / 'best.pt'
assert PRETRAIN_CKPT.exists()

from data.vocabulary import FootballVocab
from data.tokenizer import MatchTokenizer
from data.dataset import MatchDataset
from data.collator import MLMCollator
from models.d10sformer import D10Sformer, D10SformerConfig
from training.trainer import Trainer, TrainerConfig, LossSpec

# Sanity: verificamos que LossSpec ya tiene los campos nuevos
assert 'result_class_weights' in LossSpec.__dataclass_fields__, \
    'Tu trainer.py NO está actualizado. Subí la nueva versión a Drive.'
print('✓ trainer.py actualizado con soporte de class_weights')
# Out:
# ✓ trainer.py actualizado con soporte de class_weights

# %% [markdown]
# ---
# ## 2. Cargar corpus + computar distribución de clases

# %%
vocab = FootballVocab.load(VOCAB_PATH)
tokenizer = MatchTokenizer(vocab, max_seq_length=80)

with open(CORPUS_DIR / 'finetune_train.pkl', 'rb') as f:
    finetune_docs = pickle.load(f)
with open(CORPUS_DIR / 'val.pkl', 'rb') as f:
    val_docs = pickle.load(f)
with open(CORPUS_DIR / 'test.pkl', 'rb') as f:
    test_docs = pickle.load(f)

print(f'Fine-tune train: {len(finetune_docs):,}')
print(f'Val:             {len(val_docs):,}')
print(f'Test:            {len(test_docs):,}')

# Contar clases en train
train_counts = Counter()
for doc in finetune_docs:
    if doc.result is not None:
        train_counts[doc.result] += 1

n_total = sum(train_counts.values())
k = 3  # home_win, draw, away_win
n_home = train_counts['home_win']
n_draw = train_counts['draw']
n_away = train_counts['away_win']

print(f'\nDistribución TRAIN:')
print(f'  home_win: {n_home:5d}  ({100*n_home/n_total:.1f}%)')
print(f'  draw:     {n_draw:5d}  ({100*n_draw/n_total:.1f}%)')
print(f'  away_win: {n_away:5d}  ({100*n_away/n_total:.1f}%)')

# Class weights inversamente proporcionales (sklearn 'balanced')
w_home = n_total / (k * n_home)
w_draw = n_total / (k * n_draw)
w_away = n_total / (k * n_away)

# Orden = [home, draw, away] que es el orden de las heads (RESULT_HOME=0, DRAW=1, AWAY=2)
result_class_weights = [w_home, w_draw, w_away]
print(f'\nClass weights computados:')
print(f'  w_home = {w_home:.3f}')
print(f'  w_draw = {w_draw:.3f}  (mayor peso, clase minoritaria)')
print(f'  w_away = {w_away:.3f}')
# Out:
# Fine-tune train: 8,658
# Val:             1,232
# Test:            1,810
#
# Distribución TRAIN:
#   home_win:  4135  (47.8%)
#   draw:      1995  (23.0%)
#   away_win:  2528  (29.2%)
#
# Class weights computados:
#   w_home = 0.698
#   w_draw = 1.447  (mayor peso, clase minoritaria)
#   w_away = 1.142

# %% [markdown]
# ---
# ## 3. Datasets + Dataloaders (igual que 4d)

# %%
ds_train = MatchDataset(finetune_docs, tokenizer)
ds_val   = MatchDataset(val_docs, tokenizer)
ds_test  = MatchDataset(test_docs, tokenizer)

# LabelMappedCollator: convierte target_result_id y target_score_id
# de ids globales del vocab a ids locales de las heads (0..2 / 0..35).
RESULT_VOCAB_TO_LOCAL = {
    vocab.encode('RESULT_HOME_WIN'): 0,
    vocab.encode('RESULT_DRAW'):     1,
    vocab.encode('RESULT_AWAY_WIN'): 2,
}
SCORE_VOCAB_TO_LOCAL = {}
_i = 0
for _h in range(6):
    for _a in range(6):
        SCORE_VOCAB_TO_LOCAL[vocab.encode(f'SCORE_{_h}_{_a}')] = _i
        _i += 1

class LabelMappedCollator:
    def __init__(self, base):
        self.base = base
    def __call__(self, batch):
        b = self.base(batch)
        new_r = b.result_labels.clone()
        for gid, lid in RESULT_VOCAB_TO_LOCAL.items():
            new_r[b.result_labels == gid] = lid
        b.result_labels = new_r
        new_s = b.score_labels.clone()
        for gid, lid in SCORE_VOCAB_TO_LOCAL.items():
            new_s[b.score_labels == gid] = lid
        b.score_labels = new_s
        return b

collator = LabelMappedCollator(MLMCollator(vocab, mlm_probability=0.15, seed=42))

# Sanity check
_t = collator([ds_train[0]])
assert _t.result_labels.max() < 3 and _t.score_labels.max() < 36

BATCH_SIZE = 64
train_loader = DataLoader(ds_train, batch_size=BATCH_SIZE, shuffle=True,  collate_fn=collator, num_workers=0)
val_loader   = DataLoader(ds_val,   batch_size=BATCH_SIZE, shuffle=False, collate_fn=collator, num_workers=0)
test_loader  = DataLoader(ds_test,  batch_size=BATCH_SIZE, shuffle=False, collate_fn=collator, num_workers=0)

steps_per_epoch = len(train_loader)
print(f'Train batches/época: {steps_per_epoch}')
# Out:
# Train batches/época: 136

# %% [markdown]
# ---
# ## 4. Modelo + Trainer con CLASS WEIGHTS

# %%
model_config = D10SformerConfig(
    vocab_size=len(vocab),
    d_model=256, num_layers=6, num_heads=8, d_ff=1024,
    max_seq_length=80, num_segments=8,
    dropout=0.1, attention_dropout=0.1,
    pad_token_id=vocab.encode('[PAD]'),
    tie_mlm_weights=True,
)
model = D10Sformer(model_config)

# Arrancamos limpios desde el pre-train (no desde el fine-tune anterior)
ckpt = torch.load(PRETRAIN_CKPT, map_location='cpu', weights_only=False)
model.load_state_dict(ckpt['model_state_dict'])
print(f'✓ Cargado pre-train (paso {ckpt["step"]}, val_loss={ckpt["best_val_loss"]:.4f})')
# Out:
# ✓ Cargado pre-train (paso 900, val_loss=2.0678)

# %%
EPOCHS = 15
MAX_STEPS = steps_per_epoch * EPOCHS
print(f'EPOCHS = {EPOCHS}  |  Pasos totales = {MAX_STEPS}')

trainer_config = TrainerConfig(
    lr=5e-5, weight_decay=0.01, grad_clip_norm=1.0,
    warmup_ratio=0.1,
    max_steps=MAX_STEPS,
    mixed_precision=True,
    log_every=25,
    eval_every=100,
    save_every=400,
    save_best=True,
    output_dir=str(CKPT_DIR),
    run_name='finetune_weighted_15ep',
    seed=42,
)
loss_spec = LossSpec(
    use_mlm=True,    lambda_mlm=0.2,
    use_result=True, lambda_result=1.0,
    use_score=True,  lambda_score=0.3,
    result_class_weights=result_class_weights,   # ← NUEVO
)
print(f'\nLossSpec: λ_mlm={loss_spec.lambda_mlm}, λ_result={loss_spec.lambda_result}, λ_score={loss_spec.lambda_score}')
print(f'Result class weights: {result_class_weights}')

trainer = Trainer(
    model=model, train_loader=train_loader, val_loader=val_loader,
    config=trainer_config, loss_spec=loss_spec,
)
print(f'\nDevice: {trainer.device}  |  AMP: {trainer.use_amp}')
print(f'Result weights tensor: {trainer._result_weights_tensor}')
# Out:
# EPOCHS = 15  |  Pasos totales = 2040
#
# LossSpec: λ_mlm=0.2, λ_result=1.0, λ_score=0.3
# Result class weights: [0.6979443772672309, 1.4466165413533834, 1.1416139240506329]
#
# Device: cuda  |  AMP: True
# Result weights tensor: tensor([0.6979, 1.4466, 1.1416], device='cuda:0')

# %% [markdown]
# ---
# ## 5. Fine-tuning (15 épocas con class weights)

# %%
import time
t0 = time.time()
trainer.train()
elapsed = time.time() - t0
print(f'\n✓ Fine-tuning completado en {elapsed/60:.1f} min ({MAX_STEPS/elapsed:.1f} step/s)')
print(f'  Best val_loss: {trainer.best_val_loss:.4f}')
# Out:
# [step     25/2040] lr=6.13e-06  loss=2.5962  ppl=13.41  mlm_acc=0.3869  (12.9 step/s)
# [step     50/2040] lr=1.23e-05  loss=2.5619  ppl=12.96  mlm_acc=0.4005  (16.3 step/s)
# [step     75/2040] lr=1.84e-05  loss=2.5477  ppl=12.78  mlm_acc=0.4013  (17.9 step/s)
# [step    100/2040] lr=2.45e-05  loss=2.5369  ppl=12.64  mlm_acc=0.3823  (18.3 step/s)
# [eval @ step    100] val_loss=2.5052  val_ppl=12.25  val_acc=0.3884
# [step    125/2040] lr=3.06e-05  loss=2.4892  ppl=12.05  mlm_acc=0.3882  (17.6 step/s)
# [step    150/2040] lr=3.68e-05  loss=2.4619  ppl=11.73  mlm_acc=0.4057  (18.9 step/s)
# [step    175/2040] lr=4.29e-05  loss=2.4329  ppl=11.39  mlm_acc=0.4074  (20.0 step/s)
# [step    200/2040] lr=4.90e-05  loss=2.4024  ppl=11.05  mlm_acc=0.4171  (20.9 step/s)
# [eval @ step    200] val_loss=2.4194  val_ppl=11.24  val_acc=0.4064
# [step    225/2040] lr=5.00e-05  loss=2.3896  ppl=10.91  mlm_acc=0.4039  (20.4 step/s)
# [step    250/2040] lr=4.99e-05  loss=2.3370  ppl=10.35  mlm_acc=0.4147  (21.1 step/s)
# [step    275/2040] lr=4.98e-05  loss=2.3055  ppl=10.03  mlm_acc=0.4210  (21.7 step/s)
# [step    300/2040] lr=4.97e-05  loss=2.2787  ppl=9.76  mlm_acc=0.4347  (22.2 step/s)
# [eval @ step    300] val_loss=2.2832  val_ppl=9.81  val_acc=0.4129
# [step    325/2040] lr=4.95e-05  loss=2.3031  ppl=10.01  mlm_acc=0.3965  (21.6 step/s)
# [step    350/2040] lr=4.92e-05  loss=2.2930  ppl=9.90  mlm_acc=0.4102  (21.8 step/s)
# [step    375/2040] lr=4.89e-05  loss=2.2645  ppl=9.63  mlm_acc=0.4164  (21.9 step/s)
# [step    400/2040] lr=4.86e-05  loss=2.2468  ppl=9.46  mlm_acc=0.4038  (21.9 step/s)
# [eval @ step    400] val_loss=2.2735  val_ppl=9.71  val_acc=0.3995
# [step    425/2040] lr=4.82e-05  loss=2.2432  ppl=9.42  mlm_acc=0.4220  (20.8 step/s)
# [step    450/2040] lr=4.78e-05  loss=2.2179  ppl=9.19  mlm_acc=0.4310  (21.1 step/s)
# [step    475/2040] lr=4.74e-05  loss=2.2455  ppl=9.45  mlm_acc=0.4168  (21.4 step/s)
# [step    500/2040] lr=4.69e-05  loss=2.2329  ppl=9.33  mlm_acc=0.4238  (21.8 step/s)
# [eval @ step    500] val_loss=2.2098  val_ppl=9.11  val_acc=0.4166
# [step    525/2040] lr=4.63e-05  loss=2.2124  ppl=9.14  mlm_acc=0.4201  (21.5 step/s)
# [step    550/2040] lr=4.57e-05  loss=2.2046  ppl=9.07  mlm_acc=0.4128  (21.8 step/s)
# [step    575/2040] lr=4.51e-05  loss=2.2049  ppl=9.07  mlm_acc=0.4295  (22.0 step/s)
# [step    600/2040] lr=4.45e-05  loss=2.2135  ppl=9.15  mlm_acc=0.4077  (22.1 step/s)
# [eval @ step    600] val_loss=2.2098  val_ppl=9.11  val_acc=0.4351
# [step    625/2040] lr=4.38e-05  loss=2.1855  ppl=8.89  mlm_acc=0.4163  (22.0 step/s)
# [step    650/2040] lr=4.31e-05  loss=2.1717  ppl=8.77  mlm_acc=0.4354  (22.2 step/s)
# [step    675/2040] lr=4.23e-05  loss=2.1897  ppl=8.93  mlm_acc=0.4342  (22.0 step/s)
# [step    700/2040] lr=4.15e-05  loss=2.1999  ppl=9.02  mlm_acc=0.4423  (22.0 step/s)
# [eval @ step    700] val_loss=2.2047  val_ppl=9.07  val_acc=0.4174
# [step    725/2040] lr=4.07e-05  loss=2.1539  ppl=8.62  mlm_acc=0.4217  (21.5 step/s)
# [step    750/2040] lr=3.99e-05  loss=2.1904  ppl=8.94  mlm_acc=0.4302  (21.7 step/s)
# [step    775/2040] lr=3.90e-05  loss=2.1604  ppl=8.67  mlm_acc=0.4362  (21.8 step/s)
# [step    800/2040] lr=3.81e-05  loss=2.1772  ppl=8.82  mlm_acc=0.4262  (22.0 step/s)
# [eval @ step    800] val_loss=2.1926  val_ppl=8.96  val_acc=0.4336
# [step    825/2040] lr=3.72e-05  loss=2.1703  ppl=8.76  mlm_acc=0.4196  (21.1 step/s)
# [step    850/2040] lr=3.62e-05  loss=2.1707  ppl=8.76  mlm_acc=0.4482  (21.3 step/s)
# [step    875/2040] lr=3.53e-05  loss=2.1658  ppl=8.72  mlm_acc=0.4138  (21.5 step/s)
# [step    900/2040] lr=3.43e-05  loss=2.1750  ppl=8.80  mlm_acc=0.4236  (21.6 step/s)
# [eval @ step    900] val_loss=2.1904  val_ppl=8.94  val_acc=0.4267
# [step    925/2040] lr=3.33e-05  loss=2.1565  ppl=8.64  mlm_acc=0.4374  (21.4 step/s)
# [step    950/2040] lr=3.23e-05  loss=2.1606  ppl=8.68  mlm_acc=0.4206  (21.4 step/s)
# [step    975/2040] lr=3.12e-05  loss=2.1420  ppl=8.52  mlm_acc=0.4170  (21.4 step/s)
# [step   1000/2040] lr=3.02e-05  loss=2.1523  ppl=8.60  mlm_acc=0.4377  (21.2 step/s)
# [eval @ step   1000] val_loss=2.1664  val_ppl=8.73  val_acc=0.4460
# [step   1025/2040] lr=2.91e-05  loss=2.1219  ppl=8.35  mlm_acc=0.4334  (21.0 step/s)
# [step   1050/2040] lr=2.81e-05  loss=2.1653  ppl=8.72  mlm_acc=0.4268  (21.2 step/s)
# [step   1075/2040] lr=2.70e-05  loss=2.1505  ppl=8.59  mlm_acc=0.4404  (21.3 step/s)
# [step   1100/2040] lr=2.59e-05  loss=2.1423  ppl=8.52  mlm_acc=0.4322  (21.5 step/s)
# [eval @ step   1100] val_loss=2.1523  val_ppl=8.60  val_acc=0.4474
# [step   1125/2040] lr=2.49e-05  loss=2.1695  ppl=8.75  mlm_acc=0.4394  (21.3 step/s)
# [step   1150/2040] lr=2.38e-05  loss=2.1321  ppl=8.43  mlm_acc=0.4376  (21.4 step/s)
# [step   1175/2040] lr=2.27e-05  loss=2.1352  ppl=8.46  mlm_acc=0.4283  (21.6 step/s)
# [step   1200/2040] lr=2.17e-05  loss=2.1161  ppl=8.30  mlm_acc=0.4398  (21.7 step/s)
# [eval @ step   1200] val_loss=2.1601  val_ppl=8.67  val_acc=0.4412
# [step   1225/2040] lr=2.06e-05  loss=2.1204  ppl=8.33  mlm_acc=0.4544  (21.6 step/s)
# [step   1250/2040] lr=1.96e-05  loss=2.1200  ppl=8.33  mlm_acc=0.4419  (21.6 step/s)
# [step   1275/2040] lr=1.85e-05  loss=2.1368  ppl=8.47  mlm_acc=0.4223  (21.6 step/s)
# [step   1300/2040] lr=1.75e-05  loss=2.1463  ppl=8.55  mlm_acc=0.4302  (21.6 step/s)
# [eval @ step   1300] val_loss=2.1690  val_ppl=8.75  val_acc=0.4501
# [step   1325/2040] lr=1.65e-05  loss=2.1374  ppl=8.48  mlm_acc=0.4407  (21.5 step/s)
# [step   1350/2040] lr=1.55e-05  loss=2.1271  ppl=8.39  mlm_acc=0.4235  (21.5 step/s)
# [step   1375/2040] lr=1.45e-05  loss=2.1259  ppl=8.38  mlm_acc=0.4425  (21.3 step/s)
# [step   1400/2040] lr=1.36e-05  loss=2.1339  ppl=8.45  mlm_acc=0.4523  (21.3 step/s)
# [eval @ step   1400] val_loss=2.1831  val_ppl=8.87  val_acc=0.4443
# [step   1425/2040] lr=1.26e-05  loss=2.1185  ppl=8.32  mlm_acc=0.4296  (21.2 step/s)
# [step   1450/2040] lr=1.17e-05  loss=2.1323  ppl=8.43  mlm_acc=0.4283  (21.3 step/s)
# [step   1475/2040] lr=1.08e-05  loss=2.0982  ppl=8.15  mlm_acc=0.4366  (21.4 step/s)
# [step   1500/2040] lr=9.93e-06  loss=2.0955  ppl=8.13  mlm_acc=0.4304  (21.6 step/s)
# [eval @ step   1500] val_loss=2.1588  val_ppl=8.66  val_acc=0.4417
# [step   1525/2040] lr=9.09e-06  loss=2.1305  ppl=8.42  mlm_acc=0.4514  (21.5 step/s)
# [step   1550/2040] lr=8.28e-06  loss=2.1279  ppl=8.40  mlm_acc=0.4320  (21.5 step/s)
# [step   1575/2040] lr=7.50e-06  loss=2.0956  ppl=8.13  mlm_acc=0.4379  (21.5 step/s)
# [step   1600/2040] lr=6.76e-06  loss=2.1262  ppl=8.38  mlm_acc=0.4315  (21.5 step/s)
# [eval @ step   1600] val_loss=2.1676  val_ppl=8.74  val_acc=0.4452
# [step   1625/2040] lr=6.04e-06  loss=2.1267  ppl=8.39  mlm_acc=0.4546  (21.4 step/s)
# [step   1650/2040] lr=5.36e-06  loss=2.0739  ppl=7.96  mlm_acc=0.4424  (21.4 step/s)
# [step   1675/2040] lr=4.72e-06  loss=2.1062  ppl=8.22  mlm_acc=0.4394  (21.5 step/s)
# [step   1700/2040] lr=4.11e-06  loss=2.1178  ppl=8.31  mlm_acc=0.4399  (21.6 step/s)
# [eval @ step   1700] val_loss=2.1831  val_ppl=8.87  val_acc=0.4413
# [step   1725/2040] lr=3.54e-06  loss=2.1051  ppl=8.21  mlm_acc=0.4296  (21.6 step/s)
# [step   1750/2040] lr=3.02e-06  loss=2.1421  ppl=8.52  mlm_acc=0.4522  (21.6 step/s)
# [step   1775/2040] lr=2.53e-06  loss=2.1032  ppl=8.19  mlm_acc=0.4631  (21.7 step/s)
# [step   1800/2040] lr=2.08e-06  loss=2.1017  ppl=8.18  mlm_acc=0.4374  (21.7 step/s)
# [eval @ step   1800] val_loss=2.1858  val_ppl=8.90  val_acc=0.4400
# [step   1825/2040] lr=1.67e-06  loss=2.1041  ppl=8.20  mlm_acc=0.4604  (21.7 step/s)
# [step   1850/2040] lr=1.31e-06  loss=2.0978  ppl=8.15  mlm_acc=0.4308  (21.8 step/s)
# [step   1875/2040] lr=9.90e-07  loss=2.1021  ppl=8.18  mlm_acc=0.4398  (21.8 step/s)
# [step   1900/2040] lr=7.14e-07  loss=2.1236  ppl=8.36  mlm_acc=0.4480  (21.8 step/s)
# [eval @ step   1900] val_loss=2.1579  val_ppl=8.65  val_acc=0.4481
# [step   1925/2040] lr=4.82e-07  loss=2.1010  ppl=8.17  mlm_acc=0.4349  (21.7 step/s)
# [step   1950/2040] lr=2.96e-07  loss=2.1155  ppl=8.29  mlm_acc=0.4274  (21.7 step/s)
# [step   1975/2040] lr=1.54e-07  loss=2.0805  ppl=8.01  mlm_acc=0.4509  (21.8 step/s)
# [step   2000/2040] lr=5.85e-08  loss=2.1096  ppl=8.24  mlm_acc=0.4352  (21.9 step/s)
# [eval @ step   2000] val_loss=2.1878  val_ppl=8.92  val_acc=0.4342
# [step   2025/2040] lr=8.23e-09  loss=2.0892  ppl=8.08  mlm_acc=0.4534  (21.8 step/s)
#
# ✓ Fine-tuning completado en 1.6 min (21.8 step/s)
#   Best val_loss: 2.1523

# %% [markdown]
# ---
# ## 6. Evaluación detallada sobre VAL y TEST

# %%
from eval.metrics import evaluate_all

best_path = trainer.output_dir / 'best.pt'
best_ckpt = torch.load(best_path, map_location=trainer.device, weights_only=False)
model.load_state_dict(best_ckpt['model_state_dict'])
model.eval()
print(f'✓ Cargado best (step={best_ckpt["step"]}, val_loss={best_ckpt["best_val_loss"]:.4f})')

@torch.no_grad()
def predict_result_probs(loader):
    all_probs, all_true = [], []
    for batch in loader:
        batch = batch.to(trainer.device)
        out = model(batch.token_ids, batch.segment_ids, attention_mask=batch.attention_mask)
        probs = F.softmax(out['result_logits'], dim=-1).cpu().numpy()
        labels = batch.result_labels.cpu().numpy()
        for p, y in zip(probs, labels):
            if y == -100: continue
            all_probs.append(p); all_true.append(int(y))
    return np.array(all_true), np.array(all_probs)

y_val,  p_val  = predict_result_probs(val_loader)
y_test, p_test = predict_result_probs(test_loader)

metrics_val  = evaluate_all(y_val,  p_val)
metrics_test = evaluate_all(y_test, p_test)
print('\n=== D10Sformer (4e, con class weights) ===')
print(f'{"métrica":<20} {"VAL":<12} {"TEST":<12}')
for k in ['log_loss', 'brier', 'ece', 'accuracy']:
    print(f'{k:<20} {metrics_val[k]:<12.4f} {metrics_test[k]:<12.4f}')
# Out:
# ✓ Cargado best (step=1100, val_loss=2.1523)
#
# === D10Sformer (4e, con class weights) ===
# métrica              VAL          TEST
# log_loss             0.9101       0.9200
# brier                0.5371       0.5439
# ece                  0.0454       0.0531
# accuracy             0.5601       0.5514

# %%
# Confusion matrix: ¿ahora predice DRAW?
preds_val = p_val.argmax(axis=1)
cm = np.zeros((3, 3), dtype=int)
for yt, yp in zip(y_val, preds_val):
    cm[yt, yp] += 1

labels = ['home_win', 'draw', 'away_win']
fig, ax = plt.subplots(figsize=(6, 5))
im = ax.imshow(cm, cmap='Blues')
for i in range(3):
    for j in range(3):
        ax.text(j, i, str(cm[i, j]), ha='center', va='center',
                color='white' if cm[i, j] > cm.max() * 0.6 else 'black')
ax.set_xticks(range(3)); ax.set_xticklabels(labels)
ax.set_yticks(range(3)); ax.set_yticklabels(labels)
ax.set_xlabel('Predicted'); ax.set_ylabel('Actual')
ax.set_title(f'Confusion matrix (VAL, n={len(y_val)}) — con class weights')
plt.colorbar(im); plt.tight_layout(); plt.show()

print(f'\nDistribución VAL: {Counter(y_val.tolist())}')
print(f'Predicciones VAL: {Counter(preds_val.tolist())}')
print(f'\nDraws predichos: {(preds_val == 1).sum()} de {len(y_val)} ({100*(preds_val == 1).sum()/len(y_val):.1f}%)')
# Out:
# Distribución VAL: Counter({0: 579, 2: 360, 1: 293})
# Predicciones VAL: Counter({0: 505, 2: 412, 1: 315})
#
# Draws predichos: 315 de 1232 (25.6%)

# %% [markdown]
# ---
# ## 7. Comparación final: baselines vs 4d (sin weights) vs 4e (con weights)

# %%
# Baselines de Fase 1 (test)
baselines = {
    'LogReg':            {'log_loss': 0.8610, 'brier': 0.5071, 'ece': 0.0236, 'accuracy': 0.6005},
    'XGBoost':           {'log_loss': 0.8663, 'brier': 0.5105, 'ece': 0.0182, 'accuracy': 0.6026},
    'LightGBM':          {'log_loss': 0.8744, 'brier': 0.5135, 'ece': 0.0250, 'accuracy': 0.5990},
    'ELO solo':          {'log_loss': 1.0102, 'brier': 0.6101, 'ece': 0.0890, 'accuracy': 0.5510},
    'D10Sformer 4d (sin weights, test)':  {'log_loss': 0.8846, 'brier': 0.5221, 'ece': 0.0400, 'accuracy': 0.5912},
    'D10Sformer 4e (con weights, val)':   {k: metrics_val[k]  for k in ['log_loss','brier','ece','accuracy']},
    'D10Sformer 4e (con weights, test)':  {k: metrics_test[k] for k in ['log_loss','brier','ece','accuracy']},
}

import pandas as pd
df = pd.DataFrame(baselines).T
print(df.to_string(float_format=lambda x: f'{x:.4f}'))

best_baseline_ll  = min(baselines[k]['log_loss'] for k in ['LogReg','XGBoost','LightGBM'])
best_baseline_acc = max(baselines[k]['accuracy'] for k in ['LogReg','XGBoost','LightGBM'])
best_baseline_ece = min(baselines[k]['ece']      for k in ['LogReg','XGBoost','LightGBM'])

def cmp(v, ref, lower_better=True):
    if lower_better:
        return f'{"✓ GANA" if v < ref else "✗ pierde"} (Δ = {v - ref:+.4f})'
    return f'{"✓ GANA" if v > ref else "✗ pierde"} (Δ = {v - ref:+.4f})'

print(f'\n--- D10Sformer 4e (test) vs mejor baseline ---')
print(f'log_loss:  {metrics_test["log_loss"]:.4f}  vs  {best_baseline_ll:.4f}  →  {cmp(metrics_test["log_loss"], best_baseline_ll)}')
print(f'accuracy:  {metrics_test["accuracy"]:.4f}  vs  {best_baseline_acc:.4f}  →  {cmp(metrics_test["accuracy"], best_baseline_acc, lower_better=False)}')
print(f'ece:       {metrics_test["ece"]:.4f}  vs  {best_baseline_ece:.4f}  →  {cmp(metrics_test["ece"], best_baseline_ece)}')
# Out:
#                                    log_loss  brier    ece  accuracy
# LogReg                               0.8610 0.5071 0.0236    0.6005
# XGBoost                              0.8663 0.5105 0.0182    0.6026
# LightGBM                             0.8744 0.5135 0.0250    0.5990
# ELO solo                             1.0102 0.6101 0.0890    0.5510
# D10Sformer 4d (sin weights, test)    0.8846 0.5221 0.0400    0.5912
# D10Sformer 4e (con weights, val)     0.9101 0.5371 0.0454    0.5601
# D10Sformer 4e (con weights, test)    0.9200 0.5439 0.0531    0.5514
#
# --- D10Sformer 4e (test) vs mejor baseline ---
# log_loss:  0.9200  vs  0.8610  →  ✗ pierde (Δ = +0.0590)
# accuracy:  0.5514  vs  0.6026  →  ✗ pierde (Δ = -0.0512)
# ece:       0.0531  vs  0.0182  →  ✗ pierde (Δ = +0.0349)

# %% [markdown]
# ---
# ## 8. Conclusiones de Fase 4e
#
# Llenar al final:
#
# - [ ] Draws predichos VAL: _____ de 293 reales (4d eran 12)
# - [ ] D10Sformer 4e test log_loss: _____  vs LogReg 0.8610
# - [ ] D10Sformer 4e test accuracy: _____  vs XGBoost 0.6026
# - [ ] D10Sformer 4e test ECE: _____  vs XGBoost 0.0182
# - [ ] ¿Ganamos en alguna métrica? _____
# - [ ] ¿La confusion matrix se ve balanceada? _____
#
# **Decisión próxima:**
# - Si **ganamos en log_loss o ECE** → tenemos paper. Vamos a Fase 5 (eval profunda + reliability) y Fase 6 (Monte Carlo).
# - Si seguimos perdiendo pero estamos cerca (Δ < 0.01) → ablations adicionales: ELO continuo en lugar de bucketizado, sin MLM aux.
# - Si seguimos perdiendo por mucho → reportamos honestamente y usamos baselines para el Mundial.
